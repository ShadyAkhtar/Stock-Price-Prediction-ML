# %%
import pandas as pd
import math
from datetime import datetime

import numpy as np
from pandas import Series, DataFrame
import nsepy as ns

# %%
df = pd.read_csv("../datasets/data/TATAMOTORS.csv", index_col = "timestamp")

# %%
# ls

# %%
df.head()
# Out:
#              open    high     low   close  adjusted_close   volume  \
# timestamp
# 2021-03-19  303.3  311.00  290.35  308.95          308.95  5202269
# 2021-03-18  310.6  316.50  299.75  306.90          306.90  5997189
# 2021-03-17  317.0  320.00  304.00  305.85          305.85  2202123
# 2021-03-16  320.3  321.80  315.30  319.75          319.75  1860583
# 2021-03-15  320.4  320.65  310.10  318.45          318.45  2305974
#
#             dividend_amount  split_coefficient
# timestamp
# 2021-03-19              0.0                1.0
# 2021-03-18              0.0                1.0
# 2021-03-17              0.0                1.0
# 2021-03-16              0.0                1.0
# 2021-03-15              0.0                1.0

# %%
# Checking data from nse_py
# tata = ns.get_history(symbol="TATAMOTORS", 
#                     start = datetime(2005,1,1),
 #                    end = datetime(2021,3,19))

# %%
# tata.tail()

# %%
df.sort_values(["timestamp"], ascending = True, inplace=True)

# %%
df.head()
# Out:
#                 open      high       low     close  adjusted_close   volume  \
# timestamp
# 2005-01-03  488.4315  501.1275  487.7130  498.3485         91.0978  6639096
# 2005-01-04  499.5465  504.0020  496.3845  498.0610         91.0452  3195182
# 2005-01-05  493.4620  498.2530  455.1350  482.5865         88.2165  8983091
# 2005-01-06  483.8800  488.1920  470.6575  474.5380         86.7450  8203064
# 2005-01-07  472.3820  477.0770  466.6330  472.6215         86.3948  3401813
#
#             dividend_amount  split_coefficient
# timestamp
# 2005-01-03              0.0                1.0
# 2005-01-04              0.0                1.0
# 2005-01-05              0.0                1.0
# 2005-01-06              0.0                1.0
# 2005-01-07              0.0                1.0

# %%
df.tail()
# Out:
#              open    high     low   close  adjusted_close   volume  \
# timestamp
# 2021-03-15  320.4  320.65  310.10  318.45          318.45  2305974
# 2021-03-16  320.3  321.80  315.30  319.75          319.75  1860583
# 2021-03-17  317.0  320.00  304.00  305.85          305.85  2202123
# 2021-03-18  310.6  316.50  299.75  306.90          306.90  5997189
# 2021-03-19  303.3  311.00  290.35  308.95          308.95  5202269
#
#             dividend_amount  split_coefficient
# timestamp
# 2021-03-15              0.0                1.0
# 2021-03-16              0.0                1.0
# 2021-03-17              0.0                1.0
# 2021-03-18              0.0                1.0
# 2021-03-19              0.0                1.0

# %%
df.describe()
# Out:
#               open         high          low        close  adjusted_close  \
# count  3994.000000  3994.000000  3994.000000  3994.000000     3994.000000
# mean    465.625576   473.002739   457.005418   464.617675      239.936390
# std     266.691501   270.376732   262.095850   266.090409      142.123476
# min      67.050000    68.000000    63.600000    65.300000       24.038600
# 25%     269.215075   273.078300   263.542775   267.764050      129.577675
# 50%     417.626100   423.018000   410.521500   416.340250      188.597200
# 75%     622.816000   634.254500   612.994875   622.421000      354.628025
# max    1350.995500  1366.776500  1332.543000  1351.143500      598.572900
#
#              volume  dividend_amount  split_coefficient
# count  3.994000e+03      3994.000000        3994.000000
# mean   2.311925e+06         0.003443           1.000003
# std    4.535104e+06         0.071346           0.000169
# min    6.891900e+04         0.000000           1.000000
# 25%    6.860988e+05         0.000000           1.000000
# 50%    1.423384e+06         0.000000           1.000000
# 75%    2.895989e+06         0.000000           1.000000
# max    2.213711e+08         2.000000           1.010700

# %%
df = df[['open', 'high', 'low', 'close', 'adjusted_close', 'volume']]

# %%
df.head()
# Out:
#                 open      high       low     close  adjusted_close   volume
# timestamp
# 2005-01-03  488.4315  501.1275  487.7130  498.3485         91.0978  6639096
# 2005-01-04  499.5465  504.0020  496.3845  498.0610         91.0452  3195182
# 2005-01-05  493.4620  498.2530  455.1350  482.5865         88.2165  8983091
# 2005-01-06  483.8800  488.1920  470.6575  474.5380         86.7450  8203064
# 2005-01-07  472.3820  477.0770  466.6330  472.6215         86.3948  3401813

# %%
df.shape
# Out:
# (3994, 6)

# %%
df.isnull().sum()
# Out:
# open              0
# high              0
# low               0
# close             0
# adjusted_close    0
# volume            0
# dtype: int64

# %%
 df.corr()
# Out:
#                     open      high       low     close  adjusted_close  \
# open            1.000000  0.999566  0.999329  0.998968       -0.003719
# high            0.999566  1.000000  0.999261  0.999534       -0.007766
# low             0.999329  0.999261  1.000000  0.999546        0.001789
# close           0.998968  0.999534  0.999546  1.000000       -0.002896
# adjusted_close -0.003719 -0.007766  0.001789 -0.002896        1.000000
# volume          0.012531  0.018424  0.009810  0.015623       -0.246759
#
#                   volume
# open            0.012531
# high            0.018424
# low             0.009810
# close           0.015623
# adjusted_close -0.246759
# volume          1.000000

# %%
import seaborn as sns

# %%
# sns.pairplot(df)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# corrmat = df.corr()
# top_corr_features = corrmat.index
# plt.figure(figsize=(20, 20))
# #plot heat map
# g = sns.heatmap(df[top_corr_features].corr(), annot = True, cmap="RdYlGn")

# %%
## Volatility 
#high to low percent
df['HL_PCT'] = (df['high'] - df['low']) / df['close'] * 100.0

#Change percent in close to open
df['PCT_change'] = (df['close'] - df['open']) / df['open'] * 100.0

# %%
from sklearn import preprocessing
from sklearn.preprocessing import PolynomialFeatures

# %%
#Dropping missing values
df.fillna(value=-99999, inplace=True)

#separate 1 percent of data to forecast
forecast_out = int(math.ceil(0.01 * len(df)))

# separate label, we want to predict the adj close
forecast_col = 'adjusted_close'
df['label'] = df[forecast_col].shift(-forecast_out)
X = np.array(df.drop(['label'], 1))
#df.head()

# Scale X - so all have the same distribution for Linear regression
X = preprocessing.scale(X)

#finally, we want to find Data series of late X early X (train) for model generation and evaluation
X_forecast = X[-forecast_out:]
X = X[:-forecast_out]

#separate label (y)
y = np.array(df['label'])
y = y[:-forecast_out]

# %%
from sklearn.model_selection import train_test_split

# %%
#Split Data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression

# %%
#Linear regression
model = LinearRegression(n_jobs =-1)
model.fit(X_train, y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
#Accuracy of the model
confidencereg = model.score(X_test, y_test)

reg = confidencereg * 100
print(reg)
# Out:
# 91.05678680963523

# %%
forecast_reg = model.predict (X_forecast)

# %%
from datetime import timedelta
from textblob import TextBlob
import time
import nltk

# %%
df['Forecast_reg'] = np.nan

last_date = df.iloc[-1].name
last_unix = datetime.strptime(last_date, '%Y-%m-%d')
next_unix = last_unix + timedelta(days=1)

for i in forecast_reg:
    next_date = next_unix
    next_unix += timedelta(days=1)
    df.loc[next_date] = [np.nan for _ in range(len(df.columns))]
    df['Forecast_reg'].loc[next_date] = i

# %%
df.iloc[-1].name
# Out:
# Timestamp('2021-04-28 00:00:00')

# %%
df.iloc[-50:-1]
# Out:
#                       open    high     low   close  adjusted_close     volume  \
# timestamp
# 2021-03-05           334.5  337.80  319.80  325.10          325.10  7493136.0
# 2021-03-08           331.5  331.55  318.85  321.25          321.25  4669627.0
# 2021-03-09           325.3  328.25  309.70  315.20          315.20  6082763.0
# 2021-03-10           320.0  324.40  316.75  321.35          321.35  3898952.0
# 2021-03-12           325.9  326.35  314.30  317.45          317.45  2103674.0
# 2021-03-15           320.4  320.65  310.10  318.45          318.45  2305974.0
# 2021-03-16           320.3  321.80  315.30  319.75          319.75  1860583.0
# 2021-03-17           317.0  320.00  304.00  305.85          305.85  2202123.0
# 2021-03-18           310.6  316.50  299.75  306.90          306.90  5997189.0
# 2021-03-19           303.3  311.00  290.35  308.95          308.95  5202269.0
# 2021-03-20 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-03-21 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-03-22 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-03-23 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-03-24 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-03-25 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-03-26 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-03-27 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-03-28 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-03-29 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-03-30 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-03-31 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-04-01 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-04-02 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-04-03 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-04-04 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-04-05 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-04-06 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-04-07 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-04-08 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-04-09 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-04-10 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-04-11 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-04-12 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-04-13 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-04-14 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-04-15 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-04-16 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-04-17 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-04-18 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-04-19 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-04-20 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-04-21 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-04-22 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-04-23 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-04-24 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-04-25 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-04-26 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
# 2021-04-27 00:00:00    NaN     NaN     NaN     NaN             NaN        NaN
#
#                        HL_PCT  PCT_change  label  Forecast_reg
# timestamp
# 2021-03-05           5.536758   -2.810164    NaN           NaN
# 2021-03-08           3.953307   -3.092006    NaN           NaN
# 2021-03-09           5.885152   -3.104826    NaN           NaN
# 2021-03-10           2.380582    0.421875    NaN           NaN
# 2021-03-12           3.795873   -2.592820    NaN           NaN
# 2021-03-15           3.312922   -0.608614    NaN           NaN
# 2021-03-16           2.032838   -0.171714    NaN           NaN
# 2021-03-17           5.231323   -3.517350    NaN           NaN
# 2021-03-18           5.457804   -1.191243    NaN           NaN
# 2021-03-19           6.683929    1.862842    NaN           NaN
# 2021-03-20 00:00:00       NaN         NaN    NaN    319.026565
# 2021-03-21 00:00:00       NaN         NaN    NaN    307.750571
# 2021-03-22 00:00:00       NaN         NaN    NaN    293.151533
# 2021-03-23 00:00:00       NaN         NaN    NaN    276.513635
# 2021-03-24 00:00:00       NaN         NaN    NaN    281.667691
# 2021-03-25 00:00:00       NaN         NaN    NaN    277.267844
# 2021-03-26 00:00:00       NaN         NaN    NaN    289.971170
# 2021-03-27 00:00:00       NaN         NaN    NaN    355.289106
# 2021-03-28 00:00:00       NaN         NaN    NaN    352.366171
# 2021-03-29 00:00:00       NaN         NaN    NaN    334.981803
# 2021-03-30 00:00:00       NaN         NaN    NaN    321.072956
# 2021-03-31 00:00:00       NaN         NaN    NaN    343.092403
# 2021-04-01 00:00:00       NaN         NaN    NaN    329.680289
# 2021-04-02 00:00:00       NaN         NaN    NaN    338.409860
# 2021-04-03 00:00:00       NaN         NaN    NaN    331.535660
# 2021-04-04 00:00:00       NaN         NaN    NaN    329.947871
# 2021-04-05 00:00:00       NaN         NaN    NaN    337.095940
# 2021-04-06 00:00:00       NaN         NaN    NaN    333.294450
# 2021-04-07 00:00:00       NaN         NaN    NaN    334.267647
# 2021-04-08 00:00:00       NaN         NaN    NaN    323.570159
# 2021-04-09 00:00:00       NaN         NaN    NaN    312.573379
# 2021-04-10 00:00:00       NaN         NaN    NaN    312.478113
# 2021-04-11 00:00:00       NaN         NaN    NaN    334.146244
# 2021-04-12 00:00:00       NaN         NaN    NaN    338.531087
# 2021-04-13 00:00:00       NaN         NaN    NaN    343.595354
# 2021-04-14 00:00:00       NaN         NaN    NaN    329.717355
# 2021-04-15 00:00:00       NaN         NaN    NaN    334.370415
# 2021-04-16 00:00:00       NaN         NaN    NaN    352.656956
# 2021-04-17 00:00:00       NaN         NaN    NaN    354.277013
# 2021-04-18 00:00:00       NaN         NaN    NaN    346.293875
# 2021-04-19 00:00:00       NaN         NaN    NaN    332.687358
# 2021-04-20 00:00:00       NaN         NaN    NaN    325.652204
# 2021-04-21 00:00:00       NaN         NaN    NaN    320.717326
# 2021-04-22 00:00:00       NaN         NaN    NaN    327.352765
# 2021-04-23 00:00:00       NaN         NaN    NaN    318.332563
# 2021-04-24 00:00:00       NaN         NaN    NaN    319.587777
# 2021-04-25 00:00:00       NaN         NaN    NaN    322.196015
# 2021-04-26 00:00:00       NaN         NaN    NaN    306.953693
# 2021-04-27 00:00:00       NaN         NaN    NaN    314.031659

# %%
from matplotlib import style
style.use('ggplot')

# %%
plt.figure(figsize=(20,10))
df['adjusted_close'].plot()
df['Forecast_reg'].plot()

plt.legend(loc=4)
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()
